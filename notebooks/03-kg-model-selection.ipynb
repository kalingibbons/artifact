# %% [markdown]
#  # Comprehensive Exam
#
#  ## [Coding Artifact](./00-kg-main-artifact.ipynb)
#
#  Kalin Gibbons
#
#  Nov 20, 2020

# %% [markdown]
#  # Model Selection
#
#  Base selection of regressors is performed by fitting multiple regressors
#  without any prior hyperparameter tuning, then comparing the resulting errors
#  across functional groups. Models with lower errors will be marked for
#  parameter tuning investigations.

# %%
import os
import sys
import math
import logging
from pathlib import Path
from IPython.display import display

import numpy as np

import sklearn
from sklearn.ensemble import (
    AdaBoostRegressor,
    GradientBoostingRegressor,
    RandomForestRegressor
)
from sklearn.linear_model import LinearRegression, Ridge
from sklearn.multioutput import MultiOutputRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeRegressor
from tqdm.auto import tqdm


# %load_ext autoreload
# %autoreload 2

import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# import seaborn as sns
import pandas as pd

import artifact
from artifact.datasets import load_tkr, tkr_group_lut
from artifact.helpers import RegressionProfile, REGRESSION_PROFILE_PATH

# %%
plt.rcParams['figure.figsize'] = (9, 5.5)
mpl.rcParams['mathtext.fontset'] = 'stix'
mpl.rcParams['font.size'] = 14
mpl.rcParams['font.family'] = 'Times New Roman'

# sns.set_context("poster")
# sns.set(rc={'figure.figsize': (16, 9.)})
# sns.set_style("whitegrid")

pd.set_option("display.max_rows", 120)
pd.set_option("display.max_columns", 120)

logging.basicConfig(level=logging.INFO, stream=sys.stdout)

# %% [markdown]
#  ## Profiling the regressors
#
#  First, we'll choose potential regressors to investigate. Early choices are
#  linear, decision trees, as well as boosting and forest ensemble methods.
#  ### Learner Selection

# %%
learners = (
    GradientBoostingRegressor(n_estimators=100),
    RandomForestRegressor(n_estimators=100),
    AdaBoostRegressor(DecisionTreeRegressor(), n_estimators=100),
    AdaBoostRegressor(LinearRegression(), n_estimators=100),
    DecisionTreeRegressor(),
    LinearRegression()
)

# %% [markdown]
#  Next, we'll select a functional group to examine, and only load the necessary
#  data.
#  ### Functional group selection

# %%
func_groups = list(tkr_group_lut.keys())
func_groups
# Out:
# ['contact_mechanics', 'joint_loads', 'kinematics', 'ligaments', 'patella']

# %%
group = 'patella'

# %% [markdown]
#  ### Loading the data
#
#  We'll load a subset of the data containing the responses making up the chosen
#  functional group. We'll also use a `RegressionProfile` object to allow
#  persistent results.

# %%
shared_kwargs = dict(load_fcn=load_tkr, functional_group=group)
tkr_train = artifact.Results(**shared_kwargs, subset='train')
tkr_test = artifact.Results(**shared_kwargs, subset='test')
display(tkr_train.response_names[1:])

reg_prof = RegressionProfile(load_path=REGRESSION_PROFILE_PATH)
# Out:
# ['patella_area',
#  'pat_cop_1',
#  'pat_cop_2',
#  'pat_cop_3',
#  'pat_press',
#  'pat_force_1',
#  'pat_force_2',
#  'pat_force_3',
#  'pl_disp',
#  'pl_force',
#  'pat_fem_flexion',
#  'pat_fem_valgus',
#  'pat_fem_external',
#  'pat_fem_lat',
#  'pat_fem_ant',
#  'pat_fem_inf']

# %% [markdown]
#  ### Fitting and profiling
#  If the profiling results from the selected functional group have been loaded,
#  then the `force_search` flag will need to be set to `True` to overwrite the
#  previous profiling session.

# %%
force_search = False

# %%
learner_names = [x.__str__().replace('()', '') for x in learners]
scaler = StandardScaler()
regr = artifact.Regressor(tkr_train, tkr_test, learners[0], scaler=scaler)
err_df = pd.DataFrame(index=learner_names)

saved_keys = reg_prof.error_dataframes.keys()
if (force_search) or (group not in saved_keys):
    resp_pbar = tqdm(regr.train_results.response_names, desc='Processing...')
    for resp in resp_pbar:
        if resp == 'time':
            continue
        resp_pbar.set_description(f'Processing {resp}')
        errs = np.zeros_like(learner_names, dtype=np.float)
        lrn_pbar = tqdm(learners, desc='Fitting...', leave=False)
        for idx, lrn in enumerate(lrn_pbar):
            desc = f'{learner_names[idx].replace("base_estimator=", "")}'
            lrn_pbar.set_description(desc)
            regr.learner = MultiOutputRegressor(lrn)
            y_pred = regr.fit(resp).predict()
            errs[idx] = regr.prediction_error
        err_df[resp] = errs
        lrn_pbar.close()
    resp_pbar.close()

    reg_prof.add_results(group, err_df)
    reg_prof.save(REGRESSION_PROFILE_PATH)

# %% [markdown]
#  ## Results

# %%
# reg_prof.summarize(group)
for key in reg_prof.error_dataframes.keys():
    reg_prof.summarize(key)
# Out:
# joint_loads
# -----------
#
# Best learners total by response:
# LinearRegression                                                             4
# AdaBoostRegressor(base_estimator=DecisionTreeRegressor, n_estimators=100)    2
# GradientBoostingRegressor                                                    2
# dtype: int64
# med_torque_1    AdaBoostRegressor(base_estimator=DecisionTreeR...
# lat_torque_1    AdaBoostRegressor(base_estimator=DecisionTreeR...
# med_force_2                             GradientBoostingRegressor
# lat_force_2                             GradientBoostingRegressor
# med_force_1                                      LinearRegression
# med_torque_2                                     LinearRegression
# lat_force_1                                      LinearRegression
# lat_torque_2                                     LinearRegression
# dtype: object
# Sorted by median RMS error (smallest to largest):
#                                                     count        mean  \
# AdaBoostRegressor(base_estimator=DecisionTreeRe...    8.0  457.436336
# RandomForestRegressor                                 8.0  465.865525
# GradientBoostingRegressor                             8.0  453.882096
# LinearRegression                                      8.0  447.428664
# AdaBoostRegressor(base_estimator=LinearRegressi...    8.0  537.220447
# DecisionTreeRegressor                                 8.0  669.671069
#
#                                                            std        min  \
# AdaBoostRegressor(base_estimator=DecisionTreeRe...  615.357405  33.018228
# RandomForestRegressor                               624.637692  32.185607
# GradientBoostingRegressor                           605.045488  28.624252
# LinearRegression                                    586.178902  33.169663
# AdaBoostRegressor(base_estimator=LinearRegressi...  681.397757  36.384291
# DecisionTreeRegressor                               891.333514  47.775067
#
#                                                            25%         50%  \
# AdaBoostRegressor(base_estimator=DecisionTreeRe...   62.568494  175.478336
# RandomForestRegressor                                65.538200  180.323926
# GradientBoostingRegressor                            59.692740  181.805110
# LinearRegression                                     55.411237  185.267365
# AdaBoostRegressor(base_estimator=LinearRegressi...   69.945561  234.843365
# DecisionTreeRegressor                               104.640293  254.695111
#
#                                                            75%          max
# AdaBoostRegressor(base_estimator=DecisionTreeRe...  557.412198  1486.255491
# RandomForestRegressor                               567.866601  1514.090976
# GradientBoostingRegressor                           561.551478  1471.967865
# LinearRegression                                    565.693107  1430.352219
# AdaBoostRegressor(base_estimator=LinearRegressi...  709.332590  1691.947807
# DecisionTreeRegressor                               823.570689  2173.725325
# RMS Errors:
#                                                     med_force_1  med_force_2  \
# GradientBoostingRegressor                             65.327128    28.624252
# RandomForestRegressor                                 70.956263    32.185607
# AdaBoostRegressor(base_estimator=DecisionTreeRe...    67.577091    33.018228
# AdaBoostRegressor(base_estimator=LinearRegressi...    72.443998    36.384291
# DecisionTreeRegressor                                116.544116    47.775067
# LinearRegression                                      57.539003    33.169663
#
#                                                     med_torque_1  \
# GradientBoostingRegressor                             285.255098
# RandomForestRegressor                                 281.823194
# AdaBoostRegressor(base_estimator=DecisionTreeRe...    277.754143
# AdaBoostRegressor(base_estimator=LinearRegressi...    390.646228
# DecisionTreeRegressor                                 426.638880
# LinearRegression                                      311.983333
#
#                                                     med_torque_2  lat_force_1  \
# GradientBoostingRegressor                            1471.967865    78.355123
# RandomForestRegressor                                1514.090976    78.824658
# AdaBoostRegressor(base_estimator=DecisionTreeRe...   1486.255491    77.659439
# AdaBoostRegressor(base_estimator=LinearRegressi...   1691.947807    79.040501
# DecisionTreeRegressor                                2173.725325   124.552855
# LinearRegression                                     1430.352219    67.756311
#
#                                                     lat_force_2  lat_torque_1  \
# GradientBoostingRegressor                             42.789574    293.734093
# RandomForestRegressor                                 49.284010    285.853455
# AdaBoostRegressor(base_estimator=DecisionTreeRe...    47.542703    273.297233
# AdaBoostRegressor(base_estimator=LinearRegressi...    62.450251    436.239931
# DecisionTreeRegressor                                 68.928824    384.837367
# LinearRegression                                      49.027940    302.778418
#
#                                                     lat_torque_2
# GradientBoostingRegressor                            1365.003632
# RandomForestRegressor                                1413.906037
# AdaBoostRegressor(base_estimator=DecisionTreeRe...   1396.386362
# AdaBoostRegressor(base_estimator=LinearRegressi...   1528.610569
# DecisionTreeRegressor                                2014.366115
# LinearRegression                                     1326.822428
# contact_mechanics
# -----------------
#
# Best learners total by response:
# LinearRegression             5
# GradientBoostingRegressor    3
# RandomForestRegressor        2
# dtype: int64
# medial_area     GradientBoostingRegressor
# lateral_area    GradientBoostingRegressor
# lat_cop_1       GradientBoostingRegressor
# med_cop_1                LinearRegression
# med_cop_2                LinearRegression
# med_cop_3                LinearRegression
# lat_cop_2                LinearRegression
# lat_cop_3                LinearRegression
# med_press           RandomForestRegressor
# lat_press           RandomForestRegressor
# dtype: object
# Sorted by median RMS error (smallest to largest):
#                                                     count      mean       std  \
# LinearRegression                                     10.0  4.357068  4.704962
# GradientBoostingRegressor                            10.0  3.960516  3.805417
# AdaBoostRegressor(base_estimator=DecisionTreeRe...   10.0  4.065698  3.891305
# AdaBoostRegressor(base_estimator=LinearRegressi...   10.0  5.459104  5.626212
# RandomForestRegressor                                10.0  4.098140  3.929937
# DecisionTreeRegressor                                10.0  5.918483  5.702119
#
#                                                          min       25%  \
# LinearRegression                                    0.807879  1.004875
# GradientBoostingRegressor                           0.898092  1.107078
# AdaBoostRegressor(base_estimator=DecisionTreeRe...  0.950414  1.181190
# AdaBoostRegressor(base_estimator=LinearRegressi...  0.926974  1.406089
# RandomForestRegressor                               0.965873  1.212230
# DecisionTreeRegressor                               1.542130  1.854379
#
#                                                          50%       75%  \
# LinearRegression                                    1.365148  6.774553
# GradientBoostingRegressor                           1.568996  6.736251
# AdaBoostRegressor(base_estimator=DecisionTreeRe...  1.698489  6.593432
# AdaBoostRegressor(base_estimator=LinearRegressi...  1.707355  9.333867
# RandomForestRegressor                               1.729505  6.552700
# DecisionTreeRegressor                               2.538217  8.053100
#
#                                                           max
# LinearRegression                                    12.626426
# GradientBoostingRegressor                           10.675957
# AdaBoostRegressor(base_estimator=DecisionTreeRe...  11.354011
# AdaBoostRegressor(base_estimator=LinearRegressi...  14.390028
# RandomForestRegressor                               11.423556
# DecisionTreeRegressor                               16.572870
# RMS Errors:
#                                                     medial_area  lateral_area  \
# GradientBoostingRegressor                             10.675957      9.195851
# RandomForestRegressor                                 11.423556      9.541434
# AdaBoostRegressor(base_estimator=DecisionTreeRe...    11.354011      9.283727
# AdaBoostRegressor(base_estimator=LinearRegressi...    14.346280     14.390028
# DecisionTreeRegressor                                 16.572870     14.724805
# LinearRegression                                      12.626426     11.890284
#
#                                                     med_cop_1  med_cop_2  \
# GradientBoostingRegressor                            0.898092   1.051336
# RandomForestRegressor                                0.965873   1.161893
# AdaBoostRegressor(base_estimator=DecisionTreeRe...   0.950414   1.122366
# AdaBoostRegressor(base_estimator=LinearRegressi...   0.966382   0.926974
# DecisionTreeRegressor                                1.542130   1.635232
# LinearRegression                                     0.807879   0.854544
#
#                                                     med_cop_3  lat_cop_1  \
# GradientBoostingRegressor                            1.459073   0.965172
# RandomForestRegressor                                1.605035   1.128586
# AdaBoostRegressor(base_estimator=DecisionTreeRe...   1.604833   1.105410
# AdaBoostRegressor(base_estimator=LinearRegressi...   1.490307   1.378016
# DecisionTreeRegressor                                2.536910   1.843612
# LinearRegression                                     1.307279   0.966394
#
#                                                     lat_cop_2  lat_cop_3  \
# GradientBoostingRegressor                            1.274303   1.678919
# RandomForestRegressor                                1.363241   1.853975
# AdaBoostRegressor(base_estimator=DecisionTreeRe...   1.357661   1.792145
# AdaBoostRegressor(base_estimator=LinearRegressi...   1.541629   1.873082
# DecisionTreeRegressor                                1.886678   2.539525
# LinearRegression                                     1.120319   1.423017
#
#                                                     med_press  lat_press
# GradientBoostingRegressor                            5.137179   7.269275
# RandomForestRegressor                                4.801305   7.136499
# AdaBoostRegressor(base_estimator=DecisionTreeRe...   4.942756   7.143657
# AdaBoostRegressor(base_estimator=LinearRegressi...   7.849778   9.828564
# DecisionTreeRegressor                                7.748400   8.154667
# LinearRegression                                     5.312703   7.261837
# kinematics
# ----------
#
# Best learners total by response:
# LinearRegression             4
# GradientBoostingRegressor    1
# dtype: int64
# tib_fem_inf         GradientBoostingRegressor
# tib_fem_valgus               LinearRegression
# tib_fem_external             LinearRegression
# tib_fem_lat                  LinearRegression
# tib_fem_ant                  LinearRegression
# dtype: object
# Sorted by median RMS error (smallest to largest):
#                                                     count      mean       std  \
# LinearRegression                                      5.0  0.847709  0.514818
# GradientBoostingRegressor                             5.0  1.048831  0.661963
# AdaBoostRegressor(base_estimator=LinearRegressi...    5.0  1.058902  0.528898
# AdaBoostRegressor(base_estimator=DecisionTreeRe...    5.0  1.243228  0.739460
# RandomForestRegressor                                 5.0  1.253924  0.747095
# DecisionTreeRegressor                                 5.0  1.955112  1.116242
#
#                                                          min       25%  \
# LinearRegression                                    0.387899  0.465945
# GradientBoostingRegressor                           0.353070  0.749246
# AdaBoostRegressor(base_estimator=LinearRegressi...  0.466833  0.804519
# AdaBoostRegressor(base_estimator=DecisionTreeRe...  0.439947  0.838643
# RandomForestRegressor                               0.442298  0.833238
# DecisionTreeRegressor                               0.718784  1.287697
#
#                                                          50%       75%  \
# LinearRegression                                    0.670514  1.080836
# GradientBoostingRegressor                           0.775569  1.296102
# AdaBoostRegressor(base_estimator=LinearRegressi...  0.927792  1.224674
# AdaBoostRegressor(base_estimator=DecisionTreeRe...  1.013616  1.579634
# RandomForestRegressor                               1.014090  1.632387
# DecisionTreeRegressor                               1.648867  2.573168
#
#                                                          max
# LinearRegression                                    1.633352
# GradientBoostingRegressor                           2.070167
# AdaBoostRegressor(base_estimator=LinearRegressi...  1.870692
# AdaBoostRegressor(base_estimator=DecisionTreeRe...  2.344301
# RandomForestRegressor                               2.347605
# DecisionTreeRegressor                               3.547045
# RMS Errors:
#                                                     tib_fem_valgus  \
# GradientBoostingRegressor                                 0.775569
# RandomForestRegressor                                     1.014090
# AdaBoostRegressor(base_estimator=DecisionTreeRe...        1.013616
# AdaBoostRegressor(base_estimator=LinearRegressi...        0.804519
# DecisionTreeRegressor                                     1.648867
# LinearRegression                                          0.465945
#
#                                                     tib_fem_external  \
# GradientBoostingRegressor                                   2.070167
# RandomForestRegressor                                       2.347605
# AdaBoostRegressor(base_estimator=DecisionTreeRe...          2.344301
# AdaBoostRegressor(base_estimator=LinearRegressi...          1.870692
# DecisionTreeRegressor                                       3.547045
# LinearRegression                                            1.633352
#
#                                                     tib_fem_lat  tib_fem_ant  \
# GradientBoostingRegressor                              0.749246     1.296102
# RandomForestRegressor                                  0.833238     1.632387
# AdaBoostRegressor(base_estimator=DecisionTreeRe...     0.838643     1.579634
# AdaBoostRegressor(base_estimator=LinearRegressi...     0.927792     1.224674
# DecisionTreeRegressor                                  1.287697     2.573168
# LinearRegression                                       0.670514     1.080836
#
#                                                     tib_fem_inf
# GradientBoostingRegressor                              0.353070
# RandomForestRegressor                                  0.442298
# AdaBoostRegressor(base_estimator=DecisionTreeRe...     0.439947
# AdaBoostRegressor(base_estimator=LinearRegressi...     0.466833
# DecisionTreeRegressor                                  0.718784
# LinearRegression                                       0.387899
# patella
# -------
#
# Best learners total by response:
# LinearRegression             14
# GradientBoostingRegressor     2
# dtype: int64
# pat_force_3         GradientBoostingRegressor
# pat_fem_inf         GradientBoostingRegressor
# patella_area                 LinearRegression
# pat_cop_1                    LinearRegression
# pat_cop_2                    LinearRegression
# pat_cop_3                    LinearRegression
# pat_press                    LinearRegression
# pat_force_1                  LinearRegression
# pat_force_2                  LinearRegression
# pl_disp                      LinearRegression
# pl_force                     LinearRegression
# pat_fem_flexion              LinearRegression
# pat_fem_valgus               LinearRegression
# pat_fem_external             LinearRegression
# pat_fem_lat                  LinearRegression
# pat_fem_ant                  LinearRegression
# dtype: object
# Sorted by median RMS error (smallest to largest):
#                                                     count       mean  \
# LinearRegression                                     16.0   8.347111
# AdaBoostRegressor(base_estimator=LinearRegressi...   16.0  10.763468
# GradientBoostingRegressor                            16.0   8.929895
# AdaBoostRegressor(base_estimator=DecisionTreeRe...   16.0   9.359233
# RandomForestRegressor                                16.0   9.329025
# DecisionTreeRegressor                                16.0  13.628850
#
#                                                           std       min  \
# LinearRegression                                    19.601499  0.039720
# AdaBoostRegressor(base_estimator=LinearRegressi...  26.532261  0.056374
# GradientBoostingRegressor                           20.380611  0.044186
# AdaBoostRegressor(base_estimator=DecisionTreeRe...  20.774763  0.045570
# RandomForestRegressor                               20.650144  0.046053
# DecisionTreeRegressor                               29.837621  0.072473
#
#                                                          25%       50%  \
# LinearRegression                                    0.364332  0.615132
# AdaBoostRegressor(base_estimator=LinearRegressi...  0.425590  0.708399
# GradientBoostingRegressor                           0.498351  1.002280
# AdaBoostRegressor(base_estimator=DecisionTreeRe...  0.617674  1.220988
# RandomForestRegressor                               0.618356  1.275852
# DecisionTreeRegressor                               0.895509  1.869171
#
#                                                          75%         max
# LinearRegression                                    5.704172   78.473280
# AdaBoostRegressor(base_estimator=LinearRegressi...  6.811542  106.845082
# GradientBoostingRegressor                           6.213557   81.784288
# AdaBoostRegressor(base_estimator=DecisionTreeRe...  6.286227   83.039612
# RandomForestRegressor                               6.283071   82.578164
# DecisionTreeRegressor                               9.371401  119.306811
# RMS Errors:
#                                                     patella_area  pat_cop_1  \
# GradientBoostingRegressor                               3.711422   1.039986
# RandomForestRegressor                                   3.617298   1.316362
# AdaBoostRegressor(base_estimator=DecisionTreeRe...      3.642699   1.261601
# AdaBoostRegressor(base_estimator=LinearRegressi...      3.908288   0.738867
# DecisionTreeRegressor                                   5.061745   1.929259
# LinearRegression                                        3.461912   0.586916
#
#                                                     pat_cop_2  pat_cop_3  \
# GradientBoostingRegressor                            0.343133   1.429776
# RandomForestRegressor                                0.384606   1.739372
# AdaBoostRegressor(base_estimator=DecisionTreeRe...   0.378424   1.673906
# AdaBoostRegressor(base_estimator=LinearRegressi...   0.298481   1.282473
# DecisionTreeRegressor                                0.656853   2.861992
# LinearRegression                                     0.283162   1.153262
#
#                                                     pat_press  pat_force_1  \
# GradientBoostingRegressor                            2.641105    81.784288
# RandomForestRegressor                                2.763957    82.578164
# AdaBoostRegressor(base_estimator=DecisionTreeRe...   2.719691    83.039612
# AdaBoostRegressor(base_estimator=LinearRegressi...   2.845428   106.845082
# DecisionTreeRegressor                                4.004441   119.306811
# LinearRegression                                     2.242558    78.473280
#
#                                                     pat_force_2  pat_force_3  \
# GradientBoostingRegressor                             16.423624    18.257453
# RandomForestRegressor                                 17.795987    20.488181
# AdaBoostRegressor(base_estimator=DecisionTreeRe...    17.979399    20.632525
# AdaBoostRegressor(base_estimator=LinearRegressi...    15.521304    20.977951
# DecisionTreeRegressor                                 27.315488    28.032696
# LinearRegression                                      14.332141    18.449326
#
#                                                      pl_disp   pl_force  \
# GradientBoostingRegressor                           0.044186  13.719961
# RandomForestRegressor                               0.046053  14.280390
# AdaBoostRegressor(base_estimator=DecisionTreeRe...  0.045570  14.216809
# AdaBoostRegressor(base_estimator=LinearRegressi...  0.056374  16.999886
# DecisionTreeRegressor                               0.072473  22.300368
# LinearRegression                                    0.039720  12.430954
#
#                                                     pat_fem_flexion  \
# GradientBoostingRegressor                                  0.798638
# RandomForestRegressor                                      0.916872
# AdaBoostRegressor(base_estimator=DecisionTreeRe...         0.880770
# AdaBoostRegressor(base_estimator=LinearRegressi...         0.677931
# DecisionTreeRegressor                                      1.622457
# LinearRegression                                           0.643349
#
#                                                     pat_fem_valgus  \
# GradientBoostingRegressor                                 0.661859
# RandomForestRegressor                                     0.840942
# AdaBoostRegressor(base_estimator=DecisionTreeRe...        0.830537
# AdaBoostRegressor(base_estimator=LinearRegressi...        0.676898
# DecisionTreeRegressor                                     1.217882
# LinearRegression                                          0.412737
#
#                                                     pat_fem_external  \
# GradientBoostingRegressor                                   0.964573
# RandomForestRegressor                                       1.235343
# AdaBoostRegressor(base_estimator=DecisionTreeRe...          1.180376
# AdaBoostRegressor(base_estimator=LinearRegressi...          0.591485
# DecisionTreeRegressor                                       1.809084
# LinearRegression                                            0.391389
#
#                                                     pat_fem_lat  pat_fem_ant  \
# GradientBoostingRegressor                              0.545532     0.155981
# RandomForestRegressor                                  0.692568     0.172580
# AdaBoostRegressor(base_estimator=DecisionTreeRe...     0.690498     0.176108
# AdaBoostRegressor(base_estimator=LinearRegressi...     0.196462     0.130626
# DecisionTreeRegressor                                  0.975061     0.293358
# LinearRegression                                       0.134664     0.122012
#
#                                                     pat_fem_inf
# GradientBoostingRegressor                              0.356807
# RandomForestRegressor                                  0.395720
# AdaBoostRegressor(base_estimator=DecisionTreeRe...     0.399204
# AdaBoostRegressor(base_estimator=LinearRegressi...     0.467959
# DecisionTreeRegressor                                  0.601626
# LinearRegression                                       0.396402
# ligaments
# ---------
#
# Best learners total by response:
# LinearRegression    17
# dtype: int64
# ap_disp      LinearRegression
# pmc_disp     LinearRegression
# pom_disp     LinearRegression
# pol_disp     LinearRegression
# pcl_disp     LinearRegression
# pcm_disp     LinearRegression
# alc_disp     LinearRegression
# vi1_disp     LinearRegression
# pfl_force    LinearRegression
# lclp_disp    LinearRegression
# lcla_disp    LinearRegression
# lcl_disp     LinearRegression
# mclp_disp    LinearRegression
# mcla_disp    LinearRegression
# mcl_disp     LinearRegression
# pfl_disp     LinearRegression
# vi1_force    LinearRegression
# dtype: object
# Sorted by median RMS error (smallest to largest):
#                                                     count      mean  \
# LinearRegression                                     17.0  2.644678
# AdaBoostRegressor(base_estimator=LinearRegressi...   17.0  3.071228
# GradientBoostingRegressor                            17.0  3.523874
# AdaBoostRegressor(base_estimator=DecisionTreeRe...   17.0  3.898217
# RandomForestRegressor                                17.0  4.051685
# DecisionTreeRegressor                                17.0  5.993554
#
#                                                           std       min  \
# LinearRegression                                     6.578398  0.496801
# AdaBoostRegressor(base_estimator=LinearRegressi...   7.433703  0.533512
# GradientBoostingRegressor                            8.862122  0.595402
# AdaBoostRegressor(base_estimator=DecisionTreeRe...   9.532387  0.639053
# RandomForestRegressor                               10.089778  0.655742
# DecisionTreeRegressor                               14.507311  1.057411
#
#                                                          25%       50%  \
# LinearRegression                                    0.690125  0.857190
# AdaBoostRegressor(base_estimator=LinearRegressi...  0.762196  1.032230
# GradientBoostingRegressor                           0.922500  1.142407
# AdaBoostRegressor(base_estimator=DecisionTreeRe...  1.085326  1.327939
# RandomForestRegressor                               1.105437  1.344097
# DecisionTreeRegressor                               1.711025  2.147110
#
#                                                          75%        max
# LinearRegression                                    0.982690  27.809719
# AdaBoostRegressor(base_estimator=LinearRegressi...  1.193374  31.357367
# GradientBoostingRegressor                           1.385996  37.667473
# AdaBoostRegressor(base_estimator=DecisionTreeRe...  1.643020  40.645751
# RandomForestRegressor                               1.649689  42.980346
# DecisionTreeRegressor                               2.661122  61.997250
# RMS Errors:
#                                                      ap_disp  mcl_disp  \
# GradientBoostingRegressor                           1.320910  0.866712
# RandomForestRegressor                               1.649689  1.079333
# AdaBoostRegressor(base_estimator=DecisionTreeRe...  1.598345  1.054265
# AdaBoostRegressor(base_estimator=LinearRegressi...  1.234940  0.659524
# DecisionTreeRegressor                               2.596926  1.671426
# LinearRegression                                    1.095271  0.527545
#
#                                                     mcla_disp  mclp_disp  \
# GradientBoostingRegressor                            0.833466   0.895061
# RandomForestRegressor                                1.045374   1.105437
# AdaBoostRegressor(base_estimator=DecisionTreeRe...   1.020414   1.085326
# AdaBoostRegressor(base_estimator=LinearRegressi...   0.643355   0.670545
# DecisionTreeRegressor                                1.597184   1.711025
# LinearRegression                                     0.515668   0.534548
#
#                                                     lcl_disp  lcla_disp  \
# GradientBoostingRegressor                           1.302893   1.360081
# RandomForestRegressor                               1.545818   1.617806
# AdaBoostRegressor(base_estimator=DecisionTreeRe...  1.581645   1.643020
# AdaBoostRegressor(base_estimator=LinearRegressi...  1.050308   1.068814
# DecisionTreeRegressor                               2.589422   2.643307
# LinearRegression                                    0.837581   0.857190
#
#                                                     lclp_disp  pfl_disp  \
# GradientBoostingRegressor                            1.385996  1.834739
# RandomForestRegressor                                1.639246  2.155293
# AdaBoostRegressor(base_estimator=DecisionTreeRe...   1.682200  2.164975
# AdaBoostRegressor(base_estimator=LinearRegressi...   1.032230  1.193374
# DecisionTreeRegressor                                2.671249  3.263703
# LinearRegression                                     0.867430  1.092973
#
#                                                     pfl_force  alc_disp  \
# GradientBoostingRegressor                           37.667473  1.142407
# RandomForestRegressor                               42.980346  1.326170
# AdaBoostRegressor(base_estimator=DecisionTreeRe...  40.645751  1.327939
# AdaBoostRegressor(base_estimator=LinearRegressi...  31.357367  1.286204
# DecisionTreeRegressor                               61.997250  2.147110
# LinearRegression                                    27.809719  0.901664
#
#                                                     pcm_disp  pcl_disp  \
# GradientBoostingRegressor                           1.026687  0.924339
# RandomForestRegressor                               1.178683  1.035248
# AdaBoostRegressor(base_estimator=DecisionTreeRe...  1.140784  1.041014
# AdaBoostRegressor(base_estimator=LinearRegressi...  0.890204  0.998838
# DecisionTreeRegressor                               1.848993  1.668983
# LinearRegression                                    0.838817  0.876701
#
#                                                     pol_disp  pom_disp  \
# GradientBoostingRegressor                           1.078023  0.922500
# RandomForestRegressor                               1.344097  1.218054
# AdaBoostRegressor(base_estimator=DecisionTreeRe...  1.309432  1.127109
# AdaBoostRegressor(base_estimator=LinearRegressi...  1.101196  0.762196
# DecisionTreeRegressor                               2.145812  1.806551
# LinearRegression                                    0.982690  0.690125
#
#                                                     pmc_disp  vi1_disp  \
# GradientBoostingRegressor                           1.415725  0.595402
# RandomForestRegressor                               1.717247  0.655742
# AdaBoostRegressor(base_estimator=DecisionTreeRe...  1.605072  0.639053
# AdaBoostRegressor(base_estimator=LinearRegressi...  0.840768  0.533512
# DecisionTreeRegressor                               2.661122  1.057411
# LinearRegression                                    0.744542  0.496801
#
#                                                     vi1_force
# GradientBoostingRegressor                            5.333449
# RandomForestRegressor                                5.585059
# AdaBoostRegressor(base_estimator=DecisionTreeRe...   5.603342
# AdaBoostRegressor(base_estimator=LinearRegressi...   6.887504
# DecisionTreeRegressor                                7.812937
# LinearRegression                                     5.290260

# %% [markdown]
# Return to the root [Coding Artifact](./00-kg-main-artifact.ipynb) document.
